# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")
sns.set()

# %%
import glob

# %%
all_files = glob.glob('/home/ec2-user/phone_price_tool/processed_data/*.csv')
df = pd.concat((pd.read_csv(f) for f in all_files))

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'color', 'condition', 'date', 'listing_url', 'price',
#        'storage', 'url', 'carrier', 'model'],
#       dtype='object')

# %%
df.drop_duplicates(subset=['color', 'condition', 'date', 'listing_url', 'price',
       'storage', 'url', 'carrier', 'model'],inplace=True)

# %%
def viz_discrete_column(df, col):
    data = df[col].value_counts()
    ax = sns.barplot(x=data.keys(),y=data.values)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
viz_discrete_column(df,'color')

# %%
visualize_column(df,'condition')

# %%
visualize_column(df,'storage')

# %%
visualize_column(df,'carrier')

# %%
visualize_column(df,'model')

# %%
sns.distplot(df['price']);

# %%
#Clean date
a = pd.to_datetime(df.reset_index(drop=True)['date']).value_counts()
ax = sns.barplot(x=a.keys(),y=a.values)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45);
